# %% [markdown]
# <a href="https://colab.research.google.com/github/48ganesh/python/blob/main/week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Section A
#Create a function that returns True if a given inequality expression is correct and False
def check(s):
    abc=eval(s)
    if abc:
        return True
    else:
      return False
print(check("2 < 7 < 15"))
True
#Create a function that takes three arguments a, b, c and returns the sum of the numbers t
def sumDivisibles(A, B, C):
    sum = 0
    for i in range(A, B + 1):
        if (i % C == 0):
            sum += i
    return sum
     
A = int(input("Enter value of A ="))
B = int(input("Enter value of B ="))
C = int(input("Enter value of C ="))
print(sumDivisibles(A, B, C))
Enter value of A =1
Enter value of B =10
Enter value of C =3
18
#Create a function that replaces all the vowels in a string with a specified character.
def replaceVowels(str, K):
    vowels = 'AEIOUaeiou'
    for i in vowels:
      str = str.replace(i, K)
    return str
input = "My name is pratik kadam"
K = "*"
print("Given String:", input)
print("Given Specified Character:", K)
print("After replacing vowels with the specified character:", replaceVowels(input, K))
      
Given String: My name is pratik kadam
Given Specified Character: *
After replacing vowels with the specified character: My n*m* *s pr*t*k k*d*m
#Write a function that calculates the factorial of a number recursively.
def factorial(n):
    if (n==1 or n==0):
        return 1
    else:     
        return (n * factorial(n - 1))
  
num = 8
print("number : ",num)
print("Factorial : ",factorial(num))
number : 8
Factorial : 40320
#Create a function that computes the hamming distance between two strings.
def hammingDist(str1, str2):
    i = 0
    count = 0
    while(i < len(str1)):
        if(str1[i] != str2[i]):
            count += 1
        i += 1
    return count
str1 = "strong"
str2 = "strung"
print(hammingDist(str1, str2))
1
Section B
#Create a function that takes a list of non-negative integers and strings and return a new
def filter_list(l):  
    output = []
    for i in l:  
        if type(i) != str:  
            output.append(i)  
    return output
print(filter_list([14,206,'r','g',44,6,'k']))
[14, 206, 44, 6]
#The "Reverser" takes a string as input and returns that string in reverse order, with the
def reverse(str):
    str = str[::-1]
    return str.swapcase()
reverse('Hello World')
'
DLROw OLLEh
'
#with middle being everything in between the first and last element.
lst = [1, 2, 3, 4, 5, 6]
lst = first, middle, last
print(first)
print(middle)
print(last)
1
[2, 3, 4, 5]
6
#Write a function that moves all elements of one type to the end of the list.
def move_end(array, toMove):
    i = 0
    s = len(array) - 1
    while (i < s):
        while (i < s and array[s] == toMove):
            s-=1
  
        if (array[i] == toMove):
            array[i], array[s] = array[s] , array[i]
        i += 1
    return array
arr = ['a', 'a', 'a', 'b']
k = 'a'
ans = move_end(arr, k)
for i in range(len(arr)):
    print(ans[i] ,end= " ")
b a a a 
Section C
#Create a function that takes a string and returns a string in which each character is rep
def double(str):
    return ''.join([c+c for c in str])
print(double('String'))
SSttrriinngg
#Create a function that reverses a boolean value and returns the string "boolean expected"
def reverse(arg=None):
    return not arg if type(arg) == bool else "boolean expected"
print(reverse(True))
print(reverse(False))
print(reverse(0))
print(reverse(None))
False
True
boolean expected
boolean expected
#Create a function that returns the thickness (in meters) of a piece of paper after foldin
def layers(n):
    thickness = 0.5
    for _ in range(n):
        thickness *= 2
    return str(thickness / 1000)+'m' # for meters
print(layers(1))
print(layers(4))
0.001m
0.008m
#Create a function that takes a single string as argument and returns an ordered list cont
def index_of_cap(word):
    indices = []
    for i in range(len(word)):
        if word[i].isupper():
             indices.append(i)
    return indices
print(index_of_cap('Pratik'))
print(index_of_cap('eDaBiT'))
print(index_of_cap('eQuINoX'))
[0]
[1, 3, 5]
[1, 3, 4, 6]
#Using list comprehensions, create a function that finds all even numbers from 1 to the gi
def find_even_no(n):
    even =[x for x in range(2,n+1) if x % 2 == 0]
    return even
n = int(input('Enter a number : '))
find_even_no(n)
Enter a number : 12
[2, 4, 6, 8, 10, 12]
Section D
#Create a function that takes a list of strings and integers, and filters out the list so 
def filter_list(lst):
    intlst = []
    for i in lst:
        if type(i) == int:
            intlst.append(i)
    return intlst 
filter_list([1, 2, 3, 'a', 'b', 4])
[1, 2, 3, 4]
#Given a list of numbers, create a function which returns the list but with each element's
def add_index(lst):
    ind = 0
    index = []
    for i in lst:
        index.append(lst.index(i,ind) + i)
        ind+=1
    return index
add_index([1, 2, 3, 4, 5])
[1, 3, 5, 7, 9]
#Create a function that takes the height and radius of a cone as arguments and returns the
import math
pi = math.pi
def cone_volume(r, h):
    return round((1 / 3) * pi * r * r * h)
radius = float(input("Enter value of radius= "))
height = float(input("Enter value of height= "))1
print( "Volume Of Cone : ", cone_volume(radius, height) )
Enter value of radius= 5
Enter value of height= 12
Volume Of Cone : 314
#Write a function that gives the number of dots with its corresponding triangle number of 
def triangle(n):
    return n*(n+1)*0.5
n = int(input('Enter the trinalge number :'))
print("The {}th triangle has {} dots ".format(n,int(triangle(n))))
triangle(1)
Enter the trinalge number :1
The 1th triangle has 1 dots 
1.0
#Create a function that takes a list of numbers between 1 and 10 (excluding one number) an
def missing_num(lst):
    total = sum([x for x in range(11)])
    sum_of_list = sum(lst)
    return total - sum_of_list
print(missing_num([1, 2, 3, 4, 6, 7, 8, 9, 10]))
5
